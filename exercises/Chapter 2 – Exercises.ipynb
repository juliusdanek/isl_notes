# %%
#imports 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %% [markdown]
# ## Exercise 8
#
# We are going to start of with exercise 8. Here we are just doing some data exploration. I adhered to the structure that the book provides and tried to translate the R used into Python as best as possible

# %%
# a) 
# reading the csv, saved in a folder called "datasets"
df = pd.read_csv('https://github.com/juliusdanek/isl_notes/blob/master/datasets/college.csv')
# b) 
# let's look at the dataset – by looking at the first 5 rows
df.head()
# Out:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
# ...

# %%
# Let's get rid of the university name column, which is the first column
df.drop(df.columns[0], axis=1, inplace=True)
# let's look at the first 5 rows again
df.head()
# Out:
#   Private  Apps  Accept  Enroll  Top10perc  Top25perc  F.Undergrad  \
# 0     Yes  1660    1232     721         23         52         2885
# 1     Yes  2186    1924     512         16         29         2683
# 2     Yes  1428    1097     336         22         50         1036
# 3     Yes   417     349     137         60         89          510
# 4     Yes   193     146      55         16         44          249
#
#    P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  Terminal  \
# 0          537      7440        3300    450      2200   70        78
# 1         1227     12280        6450    750      1500   29        30
# 2           99     11250        3750    400      1165   53        66
# 3           63     12960        5450    450       875   92        97
# 4          869      7560        4120    800      1500   76        72
#
#    S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 0       18.1           12    7041         60
# 1       12.2           16   10527         56
# ...

# %%
# c) i.) 
# let's take a look at a summary of the numerical data
df.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %%
# ii.) 
# let's produce a scatterplot matrix akin to the R pairs function for the first 10 columns
# Here I am using seaborn, the seaborn pairgrid function is very easy to modify for other purposes too
sns.set(style="ticks", color_codes=True)
with sns.plotting_context("notebook", font_scale=1.8):
    sns.pairplot(df.iloc[:, :11])
sns.despine()
plt.tight_layout()
plt.show()

# %%
# Alternatively you can use the native Panda method
pd.tools.plotting.scatter_matrix(df.iloc[:, :11], figsize=(15,15))
plt.show()

# %%
# iii.) 
#Boxplotting outstate tuition fee grouped by whether the college is private or public
df.boxplot('Outstate', by='Private')
plt.show()

# %%
# iv.) 
#creating column Elite
df['Elite'] = df['Top10perc'] > 50
# Let's see how many colleges are "elite" colleges
df['Elite'].value_counts()
# Out:
# False    699
# True      78
# Name: Elite, dtype: int64

# %%
# showing boxplots of Outstate vs. Elite
df.boxplot('Outstate','Elite')
plt.show()

# %%
# v.)
df.hist(figsize=(12,12))
plt.show()

# %% [markdown]
# ---
# ## Exercise 9

# %%
# our new dataframe
df = pd.read_csv('../datasets/auto.csv')
# Are there any missing values? (https://stackoverflow.com/questions/29530232/python-pandas-check-if-any-value-is-nan-in-dataframe)
df.isnull().values.any()
# Out:
# False

# %%
# let's take a look at the rows
df.iloc[:10]
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0        130    3504          12.0    70
# 1  15.0          8         350.0        165    3693          11.5    70
# 2  18.0          8         318.0        150    3436          11.0    70
# 3  16.0          8         304.0        150    3433          12.0    70
# 4  17.0          8         302.0        140    3449          10.5    70
# 5  15.0          8         429.0        198    4341          10.0    70
# 6  14.0          8         454.0        220    4354           9.0    70
# 7  14.0          8         440.0        215    4312           8.5    70
# 8  14.0          8         455.0        225    4425          10.0    70
# 9  15.0          8         390.0        190    3850           8.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# ...

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  397.000000  397.000000    397.000000   397.000000    397.000000
# mean    23.515869    5.458438    193.532746  2970.261965     15.555668
# std      7.825804    1.701577    104.379583   847.904119      2.749995
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.000000  2223.000000     13.800000
# 50%     23.000000    4.000000    146.000000  2800.000000     15.500000
# 75%     29.000000    8.000000    262.000000  3609.000000     17.100000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#              year      origin
# count  397.000000  397.000000
# mean    75.994962    1.574307
# std      3.690005    0.802549
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
# horsepower doesn't seem to be stored as an int, let's check
df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# year              int64
# origin            int64
# name             object
# dtype: object

# %%
# correct! It is stored as an object. Let's try to convert it. 
try:
    df['horsepower'] = df['horsepower'].astype('int')
except Exception as e:
    print repr(e)
# Out:
# ValueError("invalid literal for long() with base 10: '?'",)

# %%
# apparently some of the values in horsepower are missing. Let's drop the rows with missing data.
# You can find the rows with ? like so: df.loc[df['horsepower'] = '?']
df = df[df['horsepower'] != '?']
# let's convert horsepower to an int
df['horsepower'] = df['horsepower'].astype('int')
df.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  392.000000  392.000000    392.000000  392.000000   392.000000
# mean    23.445918    5.471939    194.411990  104.469388  2977.584184
# std      7.805007    1.705783    104.644004   38.491160   849.402560
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.000000    4.000000    105.000000   75.000000  2225.250000
# 50%     22.750000    4.000000    151.000000   93.500000  2803.500000
# 75%     29.000000    8.000000    275.750000  126.000000  3614.750000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration        year      origin
# count    392.000000  392.000000  392.000000
# mean      15.541327   75.979592    1.576531
# std        2.758864    3.683737    0.805518
# min        8.000000   70.000000    1.000000
# 25%       13.775000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# ...

# %%
df.hist(figsize=(12,12))
plt.show()

# %% [markdown]
# a) Let's take a look at the general data. Judging from the histograms and the describe function, we can reasonably deduct that we should take a closer look at origin and cylinders.

# %%
df['origin'].value_counts()
# Out:
# 1    245
# 3     79
# 2     68
# Name: origin, dtype: int64

# %%
df['cylinders'].value_counts()
# Out:
# 4    199
# 8    103
# 6     83
# 3      4
# 5      3
# Name: cylinders, dtype: int64

# %% [markdown]
# We can assume that origin is a qualitative variable expressed in numbers, same with cylinders.

# %%
# b) + c)
# let's just use 'describe' on the quantitative columns to find the range, mean and std
df[df.columns.difference(['origin', 'cylinders'])].describe()
# Out:
#        acceleration  displacement  horsepower         mpg       weight  \
# count    392.000000    392.000000  392.000000  392.000000   392.000000
# mean      15.541327    194.411990  104.469388   23.445918  2977.584184
# std        2.758864    104.644004   38.491160    7.805007   849.402560
# min        8.000000     68.000000   46.000000    9.000000  1613.000000
# 25%       13.775000    105.000000   75.000000   17.000000  2225.250000
# 50%       15.500000    151.000000   93.500000   22.750000  2803.500000
# 75%       17.025000    275.750000  126.000000   29.000000  3614.750000
# max       24.800000    455.000000  230.000000   46.600000  5140.000000
#
#              year
# count  392.000000
# mean    75.979592
# std      3.683737
# min     70.000000
# 25%     73.000000
# 50%     76.000000
# 75%     79.000000
# max     82.000000

# %%
# d)
# excluding observations 10 to 85 and describing
df[~df.index.isin(range(10,86))].describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  317.000000  317.000000    317.000000  317.000000   317.000000
# mean    24.374763    5.381703    187.880126  101.003155  2938.854890
# std      7.872565    1.658135    100.169973   36.003208   811.640668
# min     11.000000    3.000000     68.000000   46.000000  1649.000000
# 25%     18.000000    4.000000    101.000000   75.000000  2215.000000
# 50%     23.900000    4.000000    146.000000   90.000000  2795.000000
# 75%     30.500000    6.000000    250.000000  115.000000  3520.000000
# max     46.600000    8.000000    455.000000  230.000000  4997.000000
#
#        acceleration        year      origin
# count    317.000000  317.000000  317.000000
# mean      15.704101   77.123028    1.599369
# std        2.719913    3.127158    0.819308
# min        8.500000   70.000000    1.000000
# 25%       14.000000   75.000000    1.000000
# 50%       15.500000   77.000000    1.000000
# ...

# %%
# e)
pd.tools.plotting.scatter_matrix(df, figsize=(15,15))
plt.show()

# %% [markdown]
# One can reasonably deduce a few relationship, here I will highlight three:
#
# 1. Weight & mpg – negatively correlated, higher mpg = lower weight
# 2. Displacement & mpg – negatively correlated, higher displacement = lower weight
# 3. Displacement & weight – positively correlated, higher weight = higher displacement

# %% [markdown]
# ### f)
#
# Based on the scatterplots from e), we can assume that all other variables can be useful in predicting mpg. All of them seem to have some effect / relationship with mpg. Some relationships might be weaker than others (year, acceleration, origin)

# %% [markdown]
# ---
# ## Exercise 10

# %%
# our new dataframe. Source: https://forge.scilab.org/index.php/p/rdataset/source/tree/master/csv/MASS/Boston.csv
df = pd.read_csv('../datasets/boston.csv')
df.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677082   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio       black  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %% [markdown]
# There are 506 rows in this dataset. The dataset contains the housing values in the suburbs of Boston. You can find a description of the dataset in [this pdf](https://cran.r-project.org/web/packages/MASS/MASS.pdf) on page 20.

# %%
# let's do some scatterplots
pd.tools.plotting.scatter_matrix(df, figsize=(15,15), alpha=0.2)
plt.show()

# %% [markdown]
# b)
#
# There are some relationships clearly visible:
#
# 1. Number of Rooms and Median Value
# 2. Nitrogen Oxide concentration (nox) and age
# 3. Distance to employment centers (dis) and age

# %%
# c)
# There seems to be a weak relationship between distance and crime, age and crime
df.plot(kind='scatter', x='crim', y='dis', color='r')    
df.plot(kind='scatter', x='crim', y='age', color='g')
df.plot(kind='scatter', x='crim', y='rad', color='b')
df.plot(kind='scatter', x='crim', y='tax')
df.plot(kind='scatter', x='crim', y='ptratio')
plt.show()

# %% [markdown]
# However, these observations might not be statistically significant and none of them look like they have a strong relationship.

# %%
# d)
df[['ptratio', 'crim', 'tax']].describe()
# Out:
#           ptratio        crim         tax
# count  506.000000  506.000000  506.000000
# mean    18.455534    3.613524  408.237154
# std      2.164946    8.601545  168.537116
# min     12.600000    0.006320  187.000000
# 25%     17.400000    0.082045  279.000000
# 50%     19.050000    0.256510  330.000000
# 75%     20.200000    3.677082  666.000000
# max     22.000000   88.976200  711.000000

# %% [markdown]
# There are clearly some higher values for all of these predictors. Especially in the case of tax, only a few observations has value above 666.

# %%
# e)
# 35 of the suburbs are Charles bound
df[df['chas'] == 1].describe()
# Out:
#             crim         zn      indus  chas        nox         rm        age  \
# count  35.000000  35.000000  35.000000  35.0  35.000000  35.000000   35.00000
# mean    1.851670   7.714286  12.719143   1.0   0.593426   6.519600   77.50000
# std     2.494072  18.800143   5.957623   0.0   0.144736   0.876416   22.02134
# min     0.015010   0.000000   1.210000   1.0   0.401000   5.012000   24.80000
# 25%     0.125060   0.000000   6.410000   1.0   0.489000   5.935500   60.30000
# 50%     0.447910   0.000000  13.890000   1.0   0.550000   6.250000   88.50000
# 75%     3.397665   0.000000  18.100000   1.0   0.693000   6.915000   93.20000
# max     8.982960  90.000000  19.580000   1.0   0.871000   8.780000  100.00000
#
#              dis        rad         tax    ptratio       black      lstat  \
# count  35.000000  35.000000   35.000000  35.000000   35.000000  35.000000
# mean    3.029709   9.314286  386.257143  17.491429  372.997429  11.241714
# ...

# %%
# f)
np.median(df['ptratio'])
# Out:
# 19.050000000000001

# %%
# g)
df[df['medv'] == min(df['medv'])].transpose()
# Out:
#               398       405
# crim      38.3518   67.9208
# zn         0.0000    0.0000
# indus     18.1000   18.1000
# chas       0.0000    0.0000
# nox        0.6930    0.6930
# rm         5.4530    5.6830
# age      100.0000  100.0000
# dis        1.4896    1.4254
# rad       24.0000   24.0000
# tax      666.0000  666.0000
# ptratio   20.2000   20.2000
# black    396.9000  384.9700
# lstat     30.5900   22.9800
# medv       5.0000    5.0000

# %% [markdown]
# We can see that both both of these observations lie in areas with a high crime rate and high age. However, pupil teacher ratio seems to be ok

# %%
#h)
df[df['rm'] > 7].count()
# Out:
# crim       64
# zn         64
# indus      64
# chas       64
# nox        64
# rm         64
# age        64
# dis        64
# rad        64
# tax        64
# ptratio    64
# black      64
# lstat      64
# medv       64
# dtype: int64

# %%
df[df['rm'] > 8].count()
# Out:
# crim       13
# zn         13
# indus      13
# chas       13
# nox        13
# rm         13
# age        13
# dis        13
# rad        13
# tax        13
# ptratio    13
# black      13
# lstat      13
# medv       13
# dtype: int64

# %%
df[df['rm'] > 8].describe()
# Out:
#             crim         zn      indus       chas        nox         rm  \
# count  13.000000  13.000000  13.000000  13.000000  13.000000  13.000000
# mean    0.718795  13.615385   7.078462   0.153846   0.539238   8.348538
# std     0.901640  26.298094   5.392767   0.375534   0.092352   0.251261
# min     0.020090   0.000000   2.680000   0.000000   0.416100   8.034000
# 25%     0.331470   0.000000   3.970000   0.000000   0.504000   8.247000
# 50%     0.520140   0.000000   6.200000   0.000000   0.507000   8.297000
# 75%     0.578340  20.000000   6.200000   0.000000   0.605000   8.398000
# max     3.474280  95.000000  19.580000   1.000000   0.718000   8.780000
#
#              age        dis        rad         tax    ptratio       black  \
# count  13.000000  13.000000  13.000000   13.000000  13.000000   13.000000
# mean   71.538462   3.430192   7.461538  325.076923  16.361538  385.210769
# std    24.608723   1.883955   5.332532  110.971063   2.410580   10.529359
# ...

# %% [markdown]
# They seem to be pretty average, with lower crime and lower lstat.
